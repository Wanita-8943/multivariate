# %% [markdown]
# <a href="https://colab.research.google.com/github/Wanita-8943/multivariate/blob/main/Function_Numpy_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Function

# %% [markdown]
# ![identity-function-graph.png](data:image/png;base64,...)

# %% [markdown]
# ```python
# def function_name(_Input_) :
#     do_something with _Input_ to get _Output_
#     return  _Output_
#  ```

# %% [markdown]
# function มีส่วนสำคัญทั้งหมด 4 ส่วน
#
# 1.   บอก python ว่าเราจะเขียนฟังก์ชั่น ชื่ออะไร def function_name(): (ขาดไม่ได้)
# 2.   กำหนดตัวแปรที่จะเป็น input *Input* (ขาดได้)
# 3.   ส่วนประมวลผล do_something with *Input* get *Output* (ขาดไม่ได้)
# 4.   ส่วน output return *Output* (ขาดได้)
#
# เราใช้ เว้นวรรค (indent) เพื่อบอกขอบเขตของ code

# %% [markdown]
# # สร้างฟังก์ชั่น

# %%
def print_name(name,surname,ID):
    st = f'ชื่อ {name} นามสกุล {surname} ID {ID}'
    return st
print('outside function')
# Out:
# outside function

# %% [markdown]
# การเรียกใช้ฟังก์ชั่น

# %%
print_name('วานิตา', 'สมเด็จ', '623020536-5')
# Out:
# 'ชื่อ วานิตา นามสกุล สมเด็จ ID 623020536-5'

# %%
output_string = print_name('วานิตา', 'สมเด็จ', '623020536-5')
print(output_string)
# Out:
# ชื่อ วานิตา นามสกุล สมเด็จ ID 623020536-5

# %% [markdown]
# ฟังก์ชั่นไม่จำเป็นต้องมี output

# %%
def print_name2(surname,ID,name):
    st = f'ชื่อ {name} นามสกุล {surname} รหัส {ID}'
    print(st)

# %%
print_name2('วานิตา', 'สมเด็จ', '623020536-5')
# Out:
# ชื่อ 623020536-5 นามสกุล วานิตา รหัส สมเด็จ

# %%
op2 = print_name2('วานิตา', 'สมเด็จ', '623020536-5')
# Out:
# ชื่อ 623020536-5 นามสกุล วานิตา รหัส สมเด็จ

# %%
print(op2)
# Out:
# None

# %% [markdown]
# ฟังก์ชั่นไม่จำเป็นต้องมี input

# %%
def Pi():
    return 3.14159265359

# %%
#คำนวณพื้นที่วงกลมที่ขนาดเส้นผ่านศูย์กลางเท่ากับ 3
Pi()*(1.5**2)
# Out:
# 7.0685834705775

# %%
def print_my_name():
    print('วานิตา สมเด็จ ID 623020536-5')

# %%
print_my_name()
# Out:
# วานิตา สมเด็จ ID 623020536-5

# %% [markdown]
# **1.input ของ function ใน python มีสองแบบ input ที่จำเป็นต้องใส่ กับ input ที่ไม่จำเป็นต้องใส (มีค่า default)**
#
# **2.เราต้องเรียง input ที่จำเป็นต้องใส่ขึ้นก่อน**

# %%
def print_2lines_default(name, surname, ID, grade='F'):
    st = f'ชื่อ {name} นามสกุล {surname} รหัส {ID}'
    print(st)
    st2 = f'เกรดวิชา Multivariate >>> {grade}'
    print(st2)

# %%
print_2lines_default('วานิตา', 'สมเด็จ', '623020536-5')
# Out:
# ชื่อ วานิตา นามสกุล สมเด็จ รหัส 623020536-5
# เกรดวิชา Multivariate >>> F

# %%
print_2lines_default('วานิตา', 'สมเด็จ', '623020536-5','A')
# Out:
# ชื่อ วานิตา นามสกุล สมเด็จ รหัส 623020536-5
# เกรดวิชา Multivariate >>> A

# %%
print_name2(name='วานิตา', surname='สมเด็จ', ID='623020536-5')
# Out:
# ชื่อ วานิตา นามสกุล สมเด็จ รหัส 623020536-5

# %% [markdown]
# ## HW3 ให้เขียน function คำนวณจำนวนวินาทีจากเวลาต่อไปนี้
#
# '14-15-31'
#
# '13-00-01'
#
# '05-49-44'
#
# '00-00-16'
#
# และ print ให้สวยงาม

# %%
def function_q(times):
  q = f'เวลา {times}'
  print(q)
  times_sp = times.split('-')
  answer = int(times_sp[0])*3600 + int(times_sp[1])*60 + int(times_sp[2])
  print(f'คำนวณเป็นจำนวนวินาทีได้เท่ากับ {answer} วินาที')

# %%
function_q('14-15-13')
# Out:
# เวลา 14-15-13
# คำนวณเป็นจำนวนวินาทีได้เท่ากับ 51313 วินาที

# %%
function_q('13-00-01')
# Out:
# เวลา 13-00-01
# คำนวณเป็นจำนวนวินาทีได้เท่ากับ 46801 วินาที

# %%
function_q('05-49-44')
# Out:
# เวลา 05-49-44
# คำนวณเป็นจำนวนวินาทีได้เท่ากับ 20984 วินาที

# %%
function_q('00-00-16')
# Out:
# เวลา 00-00-16
# คำนวณเป็นจำนวนวินาทีได้เท่ากับ 16 วินาที

# %% [markdown]
# Numy -> package สำหรับการจัดการกับ Array ที่เป็นตัวเลข (Matrix)
#
# Num + py -> Number-Numerical + python

# %% [markdown]
# การใช้ package
#
# 1.   import packag
# 2.   ชื่อ package.ชื่อฟังก์ชั่น#เรียกใช้ function

# %%
import numpy

# %% [markdown]
# ![ดาวน์โหลด.png](data:image/png;base64,...)

# %% [markdown]
# data structure -> array
#
# สร้าง array (numpy array)

# %%
mat_ex1 = numpy.array([[5.2,3.0,4.5],[9.1,0.1,0.3]])
print(mat_ex1)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %% [markdown]
# ชี้ค่าใน numpy array

# %%
mat_ex1[1,1] #[แถว,หลัก]
# Out:
# 0.1

# %% [markdown]
# ถ้าไม่มี numpy array

# %%
list_ex1 = [[5.2,3.0,4.5],[9.1,0.1,0.3]]
print(list_ex1)
# Out:
# [[5.2, 3.0, 4.5], [9.1, 0.1, 0.3]]

# %%
list_ex1[1,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-0fb0b321fd3a> in <module>()
# ----> 1 list_ex1[1,1]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
list_ex1[1][1]
# Out:
# 0.1

# %%
print(list_ex1)
a = list_ex1[1]
print(a)
print(a[1])
# Out:
# [[5.2, 3.0, 4.5], [9.1, 0.1, 0.3]]
# [9.1, 0.1, 0.3]
# 0.1

# %% [markdown]
# Matrix Operations
#
# data 2 แบบ -> matrix (2D array), scalar (ตัวเลขค่าคงที่)

# %%
mat_ex1 = numpy.array([[5.2,3.0,4.5],[9.1,0.1,0.3]])
print(mat_ex1)
mat_ex2 = numpy.array([[2,3.7,5.9],[91,1.5,7.3]])
print(mat_ex2)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]
# [[ 2.   3.7  5.9]
#  [91.   1.5  7.3]]

# %% [markdown]
# #**บวกกับลบ matrix เอาตัวเลขตำแหน่งเดียวกันมาบวกหรือลบกัน**
#
# (หน้าตาของ matrix ต้องเหมือนกัน)

# %%
mat_ex0 = numpy.array([[1,2],[3,4]])
print(mat_ex0)
# Out:
# [[1 2]
#  [3 4]]

# %%
mat_ex3 = mat_ex1 + mat_ex2
print(mat_ex3)
mat_ex4 = mat_ex1 - mat_ex2
print(mat_ex4)
# Out:
# [[  7.2   6.7  10.4]
#  [100.1   1.6   7.6]]
# [[  3.2  -0.7  -1.4]
#  [-81.9  -1.4  -7. ]]

# %%
mat_ex1 + mat_ex0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-806ad2057085> in <module>()
# ----> 1 mat_ex1 + mat_ex0
#
# ValueError: operands could not be broadcast together with shapes (2,3) (2,2)

# %% [markdown]
# การตรวจสอบขนาดของ matrix

# %%
mat_ex3.shape
# Out:
# (2, 3)

# %%
mat_ex3.shape[0]
# Out:
# 2

# %% [markdown]
# #**คูณ matrix**

# %% [markdown]
# ![ดาวน์โหลด (1).gif](data:image/gif;base64,...)

# %%
print(mat_ex1)
print(mat_ex1.shape)
print(mat_ex2)
print(mat_ex2.shape)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]
# (2, 3)
# [[ 2.   3.7  5.9]
#  [91.   1.5  7.3]]
# (2, 3)

# %%
mat_ex1 * mat_ex2
# Out:
# array([[1.040e+01, 1.110e+01, 2.655e+01],
#        [8.281e+02, 1.500e-01, 2.190e+00]])

# %% [markdown]
# #**การคูณ matrix (แถวคูณหลัก)**
#
# (หลักของ Matrix ตัวข้างหน้าต้องเท่ากับแถวของ Matrix ตัวข้างหลัง)
#
# (AAA,x) . (x,AAA) = (AAA,ZZZ)

# %%
numpy.dot(mat_ex1,mat_ex2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-87326e5d09ab> in <module>()
# ----> 1 numpy.dot(mat_ex1,mat_ex2)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,3) and (2,3) not aligned: 3 (dim 1) != 2 (dim 0)

# %%
print(mat_ex1)
print(mat_ex1.shape)
print(mat_ex2)
print(mat_ex2.shape)

# %% [markdown]
# #**Transpose กลับแถวเป็นหลักกลับหลักเป็นแถว**
#
# matrix.T

# %%
print(mat_ex2)
print(mat_ex2.shape)
# Out:
# [[ 2.   3.7  5.9]
#  [91.   1.5  7.3]]
# (2, 3)

# %%
print(mat_ex2.T)
print(mat_ex2.T.shape)
# Out:
# [[ 2.  91. ]
#  [ 3.7  1.5]
#  [ 5.9  7.3]]
# (3, 2)

# %%
numpy.dot(mat_ex1,mat_ex2.T) #(2,3).(3,2)
# Out:
# array([[ 48.05, 510.55],
#        [ 20.34, 830.44]])

# %%
numpy.dot(mat_ex1.T,mat_ex2) #(3,2).(2,3) = (3,3)
# Out:
# array([[838.5 ,  32.89,  97.11],
#        [ 15.1 ,  11.25,  18.43],
#        [ 36.3 ,  17.1 ,  28.74]])

# %% [markdown]
# #**HW4** อธิบายการหา Determinant และ Inverse matrix (รูปและคำอธิบาย)

# %% [markdown]
# #**การหา Determinant**
#
# การคำนวณหาดีเทอร์มิแนนต์ของเมทริกซ์ A สามารถทำได้ดังนี้
#
# เลือกสมาชิกในแถวหรือหลัก ของเมทริกซ์ A
# 1.   แล้วหาโคแฟกเตอร์ของสมาชิกในแถวหรือหลักนั้น
#  (เพื่อความง่ายนิยมเลือกแถวหรือหลักที่มีเลขศูนย์มาก)
# 2.   เอาสมาชิกแต่ละตัวในแถวหรือหลักนั้น คูณ กับ โคแฟเตอร์ของสมาชิกแล้วนำผลที่คูณได้มาบวกกัน
# ผลบวกที่ได้คือค่าดีเทอร์มิแนนต์ของเมทริกซ์ A

# %% [markdown]
# ![10.png](data:image/png;base64,...)

# %% [markdown]
# #**การหา Inverse Matrix**

# %% [markdown]
# ![12.png](data:image/png;base64,...)

# %% [markdown]
# ![13.png](data:image/png;base64,...)
